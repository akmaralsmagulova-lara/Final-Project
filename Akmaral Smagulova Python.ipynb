# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Прочитайте данные (переменную назовите 'df')
df = pd.read_csv('data.csv')

# Вывести несколько первых строк таблицы данных
print(df.head())
# Out:
#          Дата  Склад Контрагент Номенклатура  Количество
# 0  2018-01-04      1  address_0    product_0           4
# 1  2018-01-04      1  address_0    product_1           4
# 2  2018-01-04      1  address_0    product_2           5
# 3  2018-01-04      1  address_0    product_3          10
# 4  2018-01-04      1  address_0    product_4           2

# %% [markdown]
# Проверяем формат столбцов

# %% [markdown]
# #1 Сразу переведем столбец "Дата" в правильный формат

# %%
# переводим дату в datetime
df['Дата'] = pd.to_datetime(df['Дата'])

# проверяем
print(df.dtypes)
# Out:
# Дата            datetime64[ns]
# Склад                    int64
# Контрагент              object
# Номенклатура            object
# Количество               int64
# dtype: object

# %%
df.head()
# Out:
#         Дата  Склад Контрагент Номенклатура  Количество
# 0 2018-01-04      1  address_0    product_0           4
# 1 2018-01-04      1  address_0    product_1           4
# 2 2018-01-04      1  address_0    product_2           5
# 3 2018-01-04      1  address_0    product_3          10
# 4 2018-01-04      1  address_0    product_4           2

# %% [markdown]
# #2 Сгруппируйте данные по дате, посчитайте количество продаж

# %%
grouped_df = df.groupby('Дата')['Количество'].sum().reset_index()

print(grouped_df.head())
# Out:
#         Дата  Количество
# 0 2018-01-04        3734
# 1 2018-01-05        3643
# 2 2018-01-06        3193
# 3 2018-01-07        3298
# 4 2018-01-09        4055

# %% [markdown]
# Вывести несколько первых строк сгруппированных данных

# %%
grouped_df.head()
# Out:
#         Дата  Количество
# 0 2018-01-04        3734
# 1 2018-01-05        3643
# 2 2018-01-06        3193
# 3 2018-01-07        3298
# 4 2018-01-09        4055

# %% [markdown]
# #3 Нарисуйте график продаж у `grouped_df`

# %%
plt.figure(figsize=(12,6))
plt.plot(grouped_df['Дата'], grouped_df['Количество'])
plt.title('Продажи по дням')
plt.xlabel('Дата')
plt.ylabel('Количество продаж')
plt.grid()
plt.show()

# %% [markdown]
# #4 Опишите что вы видите на графике. Ваша задача - максимально описать график

# %%
Есть восходящий тренд — продажи растут от января к августу
Наблюдается чёткая сезонность внутри недели (регулярные пики и спады)
Есть резкие выбросы вниз (например, в апреле сильный провал ~2300)
Во второй половине периода волатильность увеличивается (разброс выше)
Максимальные значения достигают ~6200 → рост бизнеса

# %% [markdown]
# #5 Найдите строку, у которой максимальный выброс по количеству продаж (нужно найти выброс у `df`)

# %%
# находим строку с максимальным количеством
outlier = df.loc[df['Количество'].idxmax()]

print(outlier)
# Out:
# Дата            2018-06-28 00:00:00
# Склад                             1
# Контрагент              address_208
# Номенклатура              product_0
# Количество                      200
# Name: 218822, dtype: object

# %% [markdown]
# #5 Найдите топовый товар по продажам по средам за июнь, июль, август у 3 склада

# %%
# фильтруем склад 3
df_3 = df[df['Склад'] == 3].copy()

# добавляем день недели и месяц
df_3.loc[:, 'weekday'] = df_3['Дата'].dt.weekday
df_3.loc[:, 'month'] = df_3['Дата'].dt.month

# среда = 2 (0=понедельник)
df_wed = df_3[
    (df_3['weekday'] == 2) &
    (df_3['month'].isin([6,7,8]))
]

# группировка по товару
top_product = (
    df_wed.groupby('Номенклатура')['Количество']
    .sum()
    .sort_values(ascending=False)
    .head(1)
)

print(top_product)
# Out:
# Номенклатура
# product_1    2267
# Name: Количество, dtype: int64

# %% [markdown]
# #6 Скачайте данные по погоде с https://rp5.ru/Архив_погоды_в_Астане (скачайте исходные данные, и далее преобразуйте так, чтобы мы имели Дату и Среднюю температуру за день), объедините таблицу температуры с `grouped_df`, и нарисуйте график `y=['Количество продаж', 'T']`, где Т это температура. А также отдельно график температуры.

# %%
pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd==2.0.1
# Out:
# Collecting xlrd==2.0.1
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.2
#     Uninstalling xlrd-2.0.2:
#       Successfully uninstalled xlrd-2.0.2
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

weather = pd.read_excel('weather.xls', engine='xlrd', skiprows=6)  # если первые 6 строк не таблица
print(weather.head())
# Out:
#   Местное время в Астане     T     Po      P   Pa     U  \
# 0       31.08.2018 23:00   8.2  736.6  768.3  0.2  78.0
# 1       31.08.2018 20:00   9.6  736.4  767.9  1.2  88.0
# 2       31.08.2018 17:00  11.3  735.2  766.4  0.4  83.0
# 3       31.08.2018 14:00  12.3  734.8  765.9  0.9  80.0
# 4       31.08.2018 11:00  13.2  733.9  764.8  1.0  83.0
#
#                                        DD  Ff  ff10  ff3  ...  \
# 0          Ветер, дующий с северо-востока   4   NaN  NaN  ...
# 1    Ветер, дующий с западо-северо-запада   3   NaN  NaN  ...
# 2  Ветер, дующий с востоко-северо-востока   4   NaN  NaN  ...
# 3          Ветер, дующий с северо-востока   4   NaN  NaN  ...
# 4   Ветер, дующий с северо-северо-востока   4   NaN  NaN  ...
#
#                                                   Cm  \
# 0  Высококучевых, высокослоистых или слоисто-дожд...
# 1  Высококучевых, высокослоистых или слоисто-дожд...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                   Ch    VV    Td  \
# 0  Перистых, перисто-кучевых или перисто-слоистых...   NaN   4.6
# 1  Перистых, перисто-кучевых или перисто-слоистых...   NaN   7.7
# 2                                                NaN  10.0   8.5
# 3                                                NaN   4.0   8.9
# 4                                                NaN  10.0  10.3
#
#              RRR    tR    E  Tg   E'  sss
# 0  Следы осадков  12.0  NaN NaN  NaN  NaN
# 1  Следы осадков  12.0  NaN NaN  NaN  NaN
# 2            NaN   NaN  NaN NaN  NaN  NaN
# 3            NaN   NaN  NaN NaN  NaN  NaN
# 4              3  12.0  NaN NaN  NaN  NaN
#
# [5 rows x 29 columns]

# %%
import pandas as pd

# допустим, ваш DataFrame называется weather
weather['Дата'] = pd.to_datetime(
    weather['Местное время в Астане'],
    dayfirst=True,   # у нас формат 31.08.2018
    errors='coerce'  # чтобы некорректные значения стали NaT
)

# проверить результат
print(weather[['Местное время в Астане', 'Дата', 'T']].head())
# Out:
#   Местное время в Астане                Дата     T
# 0       31.08.2018 23:00 2018-08-31 23:00:00   8.2
# 1       31.08.2018 20:00 2018-08-31 20:00:00   9.6
# 2       31.08.2018 17:00 2018-08-31 17:00:00  11.3
# 3       31.08.2018 14:00 2018-08-31 14:00:00  12.3
# 4       31.08.2018 11:00 2018-08-31 11:00:00  13.2

# %%
print(weather.head())
# Out:
#   Местное время в Астане     T     Po      P   Pa     U  \
# 0       31.08.2018 23:00   8.2  736.6  768.3  0.2  78.0
# 1       31.08.2018 20:00   9.6  736.4  767.9  1.2  88.0
# 2       31.08.2018 17:00  11.3  735.2  766.4  0.4  83.0
# 3       31.08.2018 14:00  12.3  734.8  765.9  0.9  80.0
# 4       31.08.2018 11:00  13.2  733.9  764.8  1.0  83.0
#
#                                        DD  Ff  ff10  ff3  ...  \
# 0          Ветер, дующий с северо-востока   4   NaN  NaN  ...
# 1    Ветер, дующий с западо-северо-запада   3   NaN  NaN  ...
# 2  Ветер, дующий с востоко-северо-востока   4   NaN  NaN  ...
# 3          Ветер, дующий с северо-востока   4   NaN  NaN  ...
# 4   Ветер, дующий с северо-северо-востока   4   NaN  NaN  ...
#
#                                                   Ch    VV    Td  \
# 0  Перистых, перисто-кучевых или перисто-слоистых...   NaN   4.6
# 1  Перистых, перисто-кучевых или перисто-слоистых...   NaN   7.7
# 2                                                NaN  10.0   8.5
# 3                                                NaN   4.0   8.9
# 4                                                NaN  10.0  10.3
#
#              RRR    tR    E  Tg   E'  sss                Дата
# 0  Следы осадков  12.0  NaN NaN  NaN  NaN 2018-08-31 23:00:00
# 1  Следы осадков  12.0  NaN NaN  NaN  NaN 2018-08-31 20:00:00
# 2            NaN   NaN  NaN NaN  NaN  NaN 2018-08-31 17:00:00
# 3            NaN   NaN  NaN NaN  NaN  NaN 2018-08-31 14:00:00
# 4              3  12.0  NaN NaN  NaN  NaN 2018-08-31 11:00:00
#
# [5 rows x 30 columns]

# %%
# создаём колонку только с датой без времени
weather['День'] = weather['Дата'].dt.date

# группируем по дню и считаем среднюю температуру
daily_weather = weather.groupby('День')['T'].mean().reset_index()
daily_weather.rename(columns={'T': 'T_avg'}, inplace=True)
print(daily_weather.head())
# Out:
#          День   T_avg
# 0  2018-04-01 -7.6875
# 1  2018-04-02 -5.2625
# 2  2018-04-03 -2.1750
# 3  2018-04-04 -0.5875
# 4  2018-04-05  2.9000

# %%
grouped_df['Дата'] = pd.to_datetime(grouped_df['Дата']).dt.date

# %%
merged_df = grouped_df.merge(daily_weather, left_on='Дата', right_on='День', how='left')
print(merged_df.head())
# Out:
#          Дата  Количество День  T_avg
# 0  2018-01-04        3734  NaN    NaN
# 1  2018-01-05        3643  NaN    NaN
# 2  2018-01-06        3193  NaN    NaN
# 3  2018-01-07        3298  NaN    NaN
# 4  2018-01-09        4055  NaN    NaN

# %%
# В grouped_df оставляем только дату без времени
grouped_df['Дата_only'] = pd.to_datetime(grouped_df['Дата']).dt.date

# В daily_weather тоже должны быть date
daily_weather['День'] = pd.to_datetime(daily_weather['День']).dt.date

# Теперь merge
merged_df = grouped_df.merge(daily_weather, left_on='Дата_only', right_on='День', how='left')

print(merged_df[['Дата', 'Количество', 'T_avg']].head(10))
# Out:
#          Дата  Количество  T_avg
# 0  2018-01-04        3734    NaN
# 1  2018-01-05        3643    NaN
# 2  2018-01-06        3193    NaN
# 3  2018-01-07        3298    NaN
# 4  2018-01-09        4055    NaN
# 5  2018-01-10        3653    NaN
# 6  2018-01-11        3176    NaN
# 7  2018-01-12        3092    NaN
# 8  2018-01-13        3294    NaN
# 9  2018-01-14        3228    NaN

# %%
# Сначала приведём Местное время к datetime
weather['Дата'] = pd.to_datetime(weather['Местное время в Астане'], dayfirst=True)

# Считаем среднюю температуру по дню
daily_weather = weather.groupby(weather['Дата'].dt.date).agg(T_avg=('T','mean')).reset_index()
daily_weather.rename(columns={'Дата':'День'}, inplace=True)

# %%
# В grouped_df оставляем только дату
grouped_df['Дата_only'] = pd.to_datetime(grouped_df['Дата']).dt.date

# Merge по датам
merged_df = grouped_df.merge(daily_weather, left_on='Дата_only', right_on='День', how='left')

# Проверим результат
print(merged_df[['Дата','Количество','T_avg']].head(10))
# Out:
#          Дата  Количество  T_avg
# 0  2018-01-04        3734    NaN
# 1  2018-01-05        3643    NaN
# 2  2018-01-06        3193    NaN
# 3  2018-01-07        3298    NaN
# 4  2018-01-09        4055    NaN
# 5  2018-01-10        3653    NaN
# 6  2018-01-11        3176    NaN
# 7  2018-01-12        3092    NaN
# 8  2018-01-13        3294    NaN
# 9  2018-01-14        3228    NaN

# %%
# В grouped_df оставляем только дату без времени
grouped_df['Дата_only'] = pd.to_datetime(grouped_df['Дата']).dt.date

# В daily_weather тоже только дата
daily_weather['День'] = pd.to_datetime(daily_weather['День']).dt.date

# %%
print(set(grouped_df['Дата_only']) & set(daily_weather['День']))
# Out:
# {datetime.date(2018, 4, 12), datetime.date(2018, 5, 15), datetime.date(2018, 7, 12), datetime.date(2018, 8, 16), datetime.date(2018, 7, 6), datetime.date(2018, 5, 17), datetime.date(2018, 5, 16), datetime.date(2018, 8, 18), datetime.date(2018, 5, 20), datetime.date(2018, 4, 4), datetime.date(2018, 8, 28), datetime.date(2018, 5, 23), datetime.date(2018, 4, 21), datetime.date(2018, 5, 1), datetime.date(2018, 5, 2), datetime.date(2018, 5, 6), datetime.date(2018, 6, 1), datetime.date(2018, 6, 8), datetime.date(2018, 7, 11), datetime.date(2018, 7, 27), datetime.date(2018, 4, 8), datetime.date(2018, 4, 1), datetime.date(2018, 5, 10), datetime.date(2018, 5, 31), datetime.date(2018, 6, 7), datetime.date(2018, 6, 12), datetime.date(2018, 7, 14), datetime.date(2018, 6, 27), datetime.date(2018, 8, 11), datetime.date(2018, 5, 18), datetime.date(2018, 4, 15), datetime.date(2018, 8, 1), datetime.date(2018, 7, 28), datetime.date(2018, 8, 29), datetime.date(2018, 7, 15), datetime.date(2018, 4, 13), datetime.date(2018, 7, 17), datetime.date(2018, 7, 21), datetime.date(2018, 6, 15), datetime.date(2018, 7, 5), datetime.date(2018, 7, 1), datetime.date(2018, 5, 27), datetime.date(2018, 4, 26), datetime.date(2018, 7, 3), datetime.date(2018, 8, 14), datetime.date(2018, 8, 10), datetime.date(2018, 8, 2), datetime.date(2018, 8, 8), datetime.date(2018, 6, 3), datetime.date(2018, 8, 3), datetime.date(2018, 8, 25), datetime.date(2018, 6, 30), datetime.date(2018, 8, 21), datetime.date(2018, 6, 9), datetime.date(2018, 4, 20), datetime.date(2018, 7, 29), datetime.date(2018, 5, 19), datetime.date(2018, 6, 21), datetime.date(2018, 5, 4), datetime.date(2018, 5, 22), datetime.date(2018, 5, 13), datetime.date(2018, 4, 19), datetime.date(2018, 6, 24), datetime.date(2018, 8, 31), datetime.date(2018, 5, 5), datetime.date(2018, 6, 16), datetime.date(2018, 4, 5), datetime.date(2018, 7, 18), datetime.date(2018, 5, 26), datetime.date(2018, 8, 7), datetime.date(2018, 6, 28), datetime.date(2018, 5, 24), datetime.date(2018, 6, 13), datetime.date(2018, 8, 12), datetime.date(2018, 8, 9), datetime.date(2018, 8, 19), datetime.date(2018, 5, 29), datetime.date(2018, 6, 14), datetime.date(2018, 6, 19), datetime.date(2018, 4, 27), datetime.date(2018, 4, 11), datetime.date(2018, 7, 25), datetime.date(2018, 7, 31), datetime.date(2018, 8, 23), datetime.date(2018, 4, 25), datetime.date(2018, 4, 24), datetime.date(2018, 7, 4), datetime.date(2018, 4, 28), datetime.date(2018, 4, 22), datetime.date(2018, 7, 13), datetime.date(2018, 5, 9), datetime.date(2018, 6, 20), datetime.date(2018, 6, 29), datetime.date(2018, 5, 12), datetime.date(2018, 7, 19), datetime.date(2018, 8, 24), datetime.date(2018, 7, 7), datetime.date(2018, 4, 3), datetime.date(2018, 7, 8), datetime.date(2018, 4, 10), datetime.date(2018, 4, 29), datetime.date(2018, 6, 2), datetime.date(2018, 7, 24), datetime.date(2018, 5, 25), datetime.date(2018, 7, 26), datetime.date(2018, 6, 10), datetime.date(2018, 6, 5), datetime.date(2018, 8, 4), datetime.date(2018, 4, 18), datetime.date(2018, 7, 10), datetime.date(2018, 8, 5), datetime.date(2018, 7, 20), datetime.date(2018, 8, 15), datetime.date(2018, 8, 22), datetime.date(2018, 6, 6), datetime.date(2018, 8, 17), datetime.date(2018, 7, 22), datetime.date(2018, 6, 23), datetime.date(2018, 5, 11), datetime.date(2018, 8, 30), datetime.date(2018, 4, 6), datetime.date(2018, 6, 17), datetime.date(2018, 6, 26), datetime.date(2018, 4, 17), datetime.date(2018, 4, 7), datetime.date(2018, 5, 3), datetime.date(2018, 4, 14), datetime.date(2018, 5, 30), datetime.date(2018, 5, 8), datetime.date(2018, 8, 26), datetime.date(2018, 6, 22)}

# %%
# оставляем только даты, для которых есть погода
sales_filtered = grouped_df[grouped_df['Дата_only'].isin(daily_weather['День'])]

# %%
merged_df = sales_filtered.merge(
    daily_weather[['День','T_avg']], 
    left_on='Дата_only', 
    right_on='День', 
    how='left'
)

# %%
import matplotlib.pyplot as plt

# График Продажи и Температура
plt.figure(figsize=(12,5))
plt.plot(merged_df['Дата_only'], merged_df['Количество'], label='Количество продаж')
plt.plot(merged_df['Дата_only'], merged_df['T_avg'], label='T_avg (температура)')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# Только график температуры
plt.figure(figsize=(12,5))
plt.plot(merged_df['Дата_only'], merged_df['T_avg'], color='orange')
plt.xticks(rotation=45)
plt.ylabel('Средняя температура')
plt.show()
